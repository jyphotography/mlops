# %% [markdown]
# ## Homework
#
# In this homework, we'll deploy the ride duration model in batch mode. Like in homework 1, we'll use the Yellow Taxi Trip Records dataset.
#
# You'll find the starter code in the [homework](homework) directory.
#
# Solution: [homework_solution/](homework_solution/)

# %% [markdown]
# ## Q1. Notebook
#
# We'll start with the same notebook we ended up with in homework 1.
# We cleaned it a little bit and kept only the scoring part. You can find the initial notebook [here](homework/starter.ipynb).
#
# Run this notebook for the March 2023 data.
#
# What's the standard deviation of the predicted duration for this dataset?
#
# * 1.24
# * 6.24
# * 12.28
# * 18.28

# %%
import pickle
import pandas as pd

# %%
with open('model.bin', 'rb') as f_in:
    dv, model = pickle.load(f_in)
# Out:
# /home/codespace/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DictVectorizer from version 1.5.0 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/codespace/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator LinearRegression from version 1.5.0 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
categorical = ['PULocationID', 'DOLocationID']

def read_data(filename):
    df = pd.read_parquet(filename)
    
    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df['duration'] = df.duration.dt.total_seconds() / 60

    df = df[(df.duration >= 1) & (df.duration <= 60)].copy()

    df[categorical] = df[categorical].fillna(-1).astype('int').astype('str')
    
    return df

# %%
df = read_data('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2023-03.parquet')

# %%
dicts = df[categorical].to_dict(orient='records')
X_val = dv.transform(dicts)
y_pred = model.predict(X_val)

# %%
std_duration = y_pred.std()
print(f'Standard deviation of predicted duration: {std_duration:.2f} minutes')
# Out:
# Standard deviation of predicted duration: 6.25 minutes

# %% [markdown]
# ## Q2. Preparing the output
#
# Like in the course videos, we want to prepare the dataframe with the output.
#
# First, let's create an artificial `ride_id` column:
#
# ```python
# df['ride_id'] = f'{year:04d}/{month:02d}_' + df.index.astype('str')
# ```
#
# Next, write the ride id and the predictions to a dataframe with results.
#
# Save it as parquet:
#
# ```python
# df_result.to_parquet(
#     output_file,
#     engine='pyarrow',
#     compression=None,
#     index=False
# )
# ```
#
# What's the size of the output file?
#
# * 36M
# * 46M
# * 56M
# * 66M
# __Note:__ Make sure you use the snippet above for saving the file. It should contain only these two columns. For this question, don't change the
# dtypes of the columns and use `pyarrow`, not `fastparquet`.

# %%
year = 2023
month = 3
df['ride_id'] = f'{year:04d}/{month:02d}_' + df.index.astype('str')

# %%
df_result = pd.DataFrame()
df_result['ride_id'] = df['ride_id']
df_result['predicted_duration'] = y_pred

# %%
# !mkdir output

# %%
output_file = 'output/yellow_tripdata_2023-03.parquet'

# %%
df_result.to_parquet(
    output_file,
    engine='pyarrow',
    compression=None,
    index=False
)

# %%
# !ls -lh output
# Out:
# total 66M
# -rw-rw-rw- 1 codespace codespace 66M Jun 16 15:48 yellow_tripdata_2023-03.parquet

# %% [markdown]
# ## Q3. Creating the scoring script
#
# Now let's turn the notebook into a script.
#
# Which command you need to execute for that?

# %%
# !jupyter nbconvert --to script predict.py
# Out:
# [NbConvertApp] WARNING | pattern 'predict.py' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# =======
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
#     Equivalent to: [--JupyterApp.answer_yes=True]
# --execute
#     Execute the notebook prior to export.
#     Equivalent to: [--ExecutePreprocessor.enabled=True]
# --allow-errors
#     Continue notebook execution even if one of the cells throws an error and include the error message in the cell output (the default behaviour is to abort conversion). This flag is only relevant if '--execute' was specified, too.
#     Equivalent to: [--ExecutePreprocessor.allow_errors=True]
# --stdin
#     read a single notebook file from stdin. Write the resulting notebook with default basename 'notebook.*'
#     Equivalent to: [--NbConvertApp.from_stdin=True]
# --stdout
#     Write notebook output to stdout instead of files.
#     Equivalent to: [--NbConvertApp.writer_class=StdoutWriter]
# --inplace
#     Run nbconvert in place, overwriting the existing notebook (only
#             relevant when converting to notebook format)
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory=]
# --clear-output
#     Clear output of current file and save in place,
#             overwriting the existing notebook.
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory= --ClearOutputPreprocessor.enabled=True]
# --no-prompt
#     Exclude input and output prompts from converted document.
#     Equivalent to: [--TemplateExporter.exclude_input_prompt=True --TemplateExporter.exclude_output_prompt=True]
# --no-input
#     Exclude input cells and output prompts from converted document.
#             This mode is ideal for generating code-free reports.
#     Equivalent to: [--TemplateExporter.exclude_output_prompt=True --TemplateExporter.exclude_input=True --TemplateExporter.exclude_input_prompt=True]
# --allow-chromium-download
#     Whether to allow downloading chromium if no suitable version is found on the system.
#     Equivalent to: [--WebPDFExporter.allow_chromium_download=True]
# --disable-chromium-sandbox
#     Disable chromium security sandbox when converting to PDF..
#     Equivalent to: [--WebPDFExporter.disable_sandbox=True]
# --show-input
#     Shows code input. This flag is only useful for dejavu users.
#     Equivalent to: [--TemplateExporter.exclude_input=False]
# --embed-images
#     Embed the images as base64 dataurls in the output. This flag is only useful for the HTML/WebPDF/Slides exports.
#     Equivalent to: [--HTMLExporter.embed_images=True]
# --log-level=<Enum>
#     Set the log level by value or name.
#     Choices: any of [0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL']
#     Default: 30
#     Equivalent to: [--Application.log_level]
# --config=<Unicode>
#     Full path of a config file.
#     Default: ''
#     Equivalent to: [--JupyterApp.config_file]
# --to=<Unicode>
#     The export format to be used, either one of the built-in formats
#             ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'rst', 'script', 'slides', 'webpdf']
#             or a dotted object name that represents the import path for an
#             ``Exporter`` class
#     Default: ''
#     Equivalent to: [--NbConvertApp.export_format]
# --template=<Unicode>
#     Name of the template to use
#     Default: ''
#     Equivalent to: [--TemplateExporter.template_name]
# --template-file=<Unicode>
#     Name of the template file to use
#     Default: None
#     Equivalent to: [--TemplateExporter.template_file]
# --theme=<Unicode>
#     Template specific theme(e.g. the name of a JupyterLab CSS theme distributed
#     as prebuilt extension for the lab template)
#     Default: 'light'
#     Equivalent to: [--HTMLExporter.theme]
# --writer=<DottedObjectName>
#     Writer class used to write the
#                                         results of the conversion
#     Default: 'FilesWriter'
#     Equivalent to: [--NbConvertApp.writer_class]
# --post=<DottedOrNone>
#     PostProcessor class used to write the
#                                         results of the conversion
#     Default: ''
#     Equivalent to: [--NbConvertApp.postprocessor_class]
# --output=<Unicode>
#     overwrite base name use for output files.
#                 can only be used when converting one notebook at a time.
#     Default: ''
#     Equivalent to: [--NbConvertApp.output_base]
# --output-dir=<Unicode>
#     Directory to write output(s) to. Defaults
#                                   to output to the directory of each notebook. To recover
#                                   previous default behaviour (outputting to the current
#                                   working directory) use . as the flag value.
#     Default: ''
#     Equivalent to: [--FilesWriter.build_directory]
# --reveal-prefix=<Unicode>
#     The URL prefix for reveal.js (version 3.x).
#             This defaults to the reveal CDN, but can be any url pointing to a copy
#             of reveal.js.
#             For speaker notes to work, this must be a relative path to a local
#             copy of reveal.js: e.g., "reveal.js".
#             If a relative path is given, it must be a subdirectory of the
#             current directory (from which the server is run).
#             See the usage documentation
#             (https://nbconvert.readthedocs.io/en/latest/usage.html#reveal-js-html-slideshow)
#             for more details.
#     Default: ''
#     Equivalent to: [--SlidesExporter.reveal_url_prefix]
# --nbformat=<Enum>
#     The nbformat version to write.
#             Use this to downgrade notebooks.
#     Choices: any of [1, 2, 3, 4]
#     Default: 4
#     Equivalent to: [--NotebookExporter.nbformat_version]
#
# Examples
# --------
#
#     The simplest way to use nbconvert is
#
#             > jupyter nbconvert mynotebook.ipynb --to html
#
#             Options include ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'rst', 'script', 'slides', 'webpdf'].
#
#             > jupyter nbconvert --to latex mynotebook.ipynb
#
#             Both HTML and LaTeX support multiple output templates. LaTeX includes
#             'base', 'article' and 'report'.  HTML includes 'basic', 'lab' and
#             'classic'. You can specify the flavor of the format used.
#
#             > jupyter nbconvert --to html --template lab mynotebook.ipynb
#
#             You can also pipe the output to stdout, rather than a file
#
#             > jupyter nbconvert mynotebook.ipynb --stdout
#
#             PDF is generated via latex
#
#             > jupyter nbconvert mynotebook.ipynb --to pdf
#
#             You can get (and serve) a Reveal.js-powered slideshow
#
#             > jupyter nbconvert myslides.ipynb --to slides --post serve
#
#             Multiple notebooks can be given at the command line in a couple of
#             different ways:
#
#             > jupyter nbconvert notebook*.ipynb
#             > jupyter nbconvert notebook1.ipynb notebook2.ipynb
#
#             or you can specify the notebooks list in a config file, containing::
#
#                 c.NbConvertApp.notebooks = ["my_notebook.ipynb"]
#
#             > jupyter nbconvert --config mycfg.py
#
# To see all available configurables, use `--help-all`.

# %% [markdown]
# ## Q4. Virtual environment
#
# Now let's put everything into a virtual environment. We'll use pipenv for that.
#
# Install all the required libraries. Pay attention to the Scikit-Learn version: it should be the same as in the starter
# notebook.
#
# After installing the libraries, pipenv creates two files: `Pipfile`
# and `Pipfile.lock`. The `Pipfile.lock` file keeps the hashes of the
# dependencies we use for the virtual env.
#
# What's the first hash for the Scikit-Learn dependency?

# %%
# !pipenv install scikit-learn==1.5.0 pandas --python=3.10.13 pyarrow
# Out:
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Installing scikit-learn==1.5.0...
# ✔ Installation Succeeded
# Installing pandas...
# ✔ Installation Succeeded
# Installing pyarrow...
# ✔ Installation Succeeded
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Installing dependencies from Pipfile.lock (252d73)...
# All dependencies are now up-to-date!
# Upgrading scikit-learn==1.5.0, pandas, pyarrow in  dependencies.
# Building requirements...
# Resolving dependencies....
# ✔ Success! Locking packages...
# ⠦ Locking packages...
# Building requirements...
# Resolving dependencies....
# ✔ Success! Locking packages...
# ⠇ Locking packages...
# Building requirements...
# Resolving dependencies....
# ✔ Success! Locking packages...
# ⠇ Locking packages...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Installing dependencies from Pipfile.lock (86940c)...
# All dependencies are now up-to-date!
# Installing dependencies from Pipfile.lock (86940c)...

# %% [markdown]
# ## Q5. Parametrize the script
#
# Let's now make the script configurable via CLI. We'll create two
# parameters: year and month.
#
# Run the script for April 2023.
#
# What's the mean predicted duration?
#
# * 7.29
# * 14.29
# * 21.29
# * 28.29

# %%
# !python batch.py 2023 4
# Out:
# /home/codespace/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator DictVectorizer from version 1.5.0 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/codespace/anaconda3/lib/python3.9/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator LinearRegression from version 1.5.0 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# predicted mean duration: 14.292282936862449

# %% [markdown]
# ## Q6. Docker container
#
# Finally, we'll package the script in the docker container.
# For that, you'll need to use a base image that we prepared.
#
# This is what the content of this image is:
#
# ```dockerfile
# FROM python:3.10.13-slim
#
# WORKDIR /app
# COPY [ "model2.bin", "model.bin" ]
# ```
#
# Note: you don't need to run it. We have already done it.
#
# It is pushed to [`agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim`](https://hub.docker.com/layers/agrigorev/zoomcamp-model/mlops-2024-3.10.13-slim/images/sha256-f54535b73a8c3ef91967d5588de57d4e251b22addcbbfb6e71304a91c1c7027f?context=repo),
# which you need to use as your base image.
#
# That is, your Dockerfile should start with:
#
# ```dockerfile
# FROM agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim
#
# # do stuff here
# ```
#
# This image already has a pickle file with a dictionary vectorizer
# and a model. You will need to use them.
#
# Important: don't copy the model to the docker image. You will need
# to use the pickle file already in the image.
#
# Now run the script with docker. What's the mean predicted duration
# for May 2023?
#
# * 0.19
# * 7.24
# * 14.24
# * 21.19

# %%
# !docker build -t ride-duration-prediction-service:v1 .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 0.2s (3/3)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
# [+] Building 0.4s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.2s
# [+] Building 0.6s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.3s
# [+] Building 0.7s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.5s
# [+] Building 0.9s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.6s
# [+] Building 1.0s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.8s
# [+] Building 1.2s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               0.9s
# [+] Building 1.3s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.1s
# [+] Building 1.5s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.2s
# [+] Building 1.6s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.4s
# [+] Building 1.8s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.5s
# [+] Building 1.9s (7/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
# [+] Building 2.0s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
# [+] Building 2.2s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             0.2s
# [+] Building 2.3s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             0.3s
# [+] Building 2.5s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             0.5s
# [+] Building 2.6s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             0.6s
# [+] Building 2.6s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             0.6s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 2.8s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             0.8s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 2.9s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             0.9s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 3.1s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             1.1s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 3.2s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             1.2s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 3.4s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             1.4s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 3.5s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             1.5s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 3.7s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             1.7s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 3.8s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             1.8s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 4.0s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             2.0s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 4.1s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             2.1s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 4.3s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             2.3s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 4.4s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             2.4s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 4.6s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             2.6s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 4.7s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             2.7s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 4.9s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             2.9s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 5.0s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             3.0s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 5.2s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             3.2s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 5.3s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             3.3s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 5.5s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             3.5s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 5.6s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             3.6s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 5.8s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             3.8s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 5.9s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             3.9s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 6.1s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             4.1s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 6.2s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             4.2s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 6.4s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             4.4s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 6.5s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             4.5s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 6.7s (8/10)                                         docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                             4.7s
#  => => # Installing dependencies from Pipfile.lock (86940c)...
# [+] Building 6.8s (8/10)                                         docker:default
# ...
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     1.8s
#  => => exporting layers                                                    1.8s
# [+] Building 28.2s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     2.0s
#  => => exporting layers                                                    2.0s
# [+] Building 28.4s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    2.1s
# [+] Building 28.5s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     2.3s
#  => => exporting layers                                                    2.3s
# [+] Building 28.7s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     2.4s
#  => => exporting layers                                                    2.4s
# [+] Building 28.8s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     2.6s
#  => => exporting layers                                                    2.6s
# [+] Building 29.0s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     2.7s
#  => => exporting layers                                                    2.7s
# [+] Building 29.1s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     2.9s
#  => => exporting layers                                                    2.9s
# [+] Building 29.3s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     3.0s
#  => => exporting layers                                                    3.0s
# [+] Building 29.4s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     3.2s
#  => => exporting layers                                                    3.2s
# [+] Building 29.6s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     3.3s
#  => => exporting layers                                                    3.3s
# [+] Building 29.7s (10/11)                                       docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     3.4s
#  => => exporting layers                                                    3.4s
# [+] Building 29.8s (11/11) FINISHED                              docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 287B                                       0.0s
#  => [internal] load metadata for docker.io/agrigorev/zoomcamp-model:mlops  0.2s
#  => [auth] agrigorev/zoomcamp-model:pull token for registry-1.docker.io    0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/5] FROM docker.io/agrigorev/zoomcamp-model:mlops-2024-3.10.13-slim  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 20.77kB                                       0.0s
#  => CACHED [2/5] RUN pip install -U pip & pip install pipenv               0.0s
#  => [3/5] COPY [ Pipfile, Pipfile.lock, ./ ]                               1.7s
#  => [4/5] RUN pipenv install --system --deploy                            24.2s
#  => [5/5] COPY [ batch.py, batch.py ]                                      0.0s
#  => exporting to image                                                     3.4s
#  => => exporting layers                                                    3.4s
#  => => writing image sha256:013eafc52f82377a0c275f3243c19151b7eb2940dd32c  0.0s
#  => => naming to docker.io/library/ride-duration-prediction-service:v1     0.0s

# %%
# !docker run --rm -it ride-duration-prediction-service:v1 2023 5
# Out:
# predicted mean duration: 0.19174419265916945
